# %% [markdown]
# # Лекция 3
#
# ## Введение в Python

# %% [markdown]
# ## ДЗ

# %% [markdown]
# ## 1] Вывод дерева директории (*)
# Разработать функцию вывода директории в виде дерева (путь до директории подается в качестве входного параметра функции). При этом сначала выводятся все папки директории, затем все файлы. Напротив папок ставить знак `(d)`.
#
# В процессе выполнения задачи следует разобраться в модуле `os`, научиться с ним работать
# (ссылка на документацию для более глубокого изучения: https://docs.python.org/3/library/os.html).
#
# Пример вывода программы:
# ```
# .
# ├── maven_repos (d)
# ├── release (d)
# │   ├── release_d1 (d)
# │   │   └── release_d1_f1.txt
# │   ├── release_f1.txt
# │   └── release_f2
# ├── svn (d)
# │   ├── svn_d1 (d)
# │   ├── svn_d2 (d)
# │   └── svn_f1.txt
# └── file_1.txt
# ```

# %% [markdown]
# ## 2] Создать генератор случайной неубывающей последовательности чисел
# Разобраться в модуле `random`, реализовать генератор, принимающий 3 параметра: длину последовательности, минимальное значение выходных чисел, максимальное значение выходных чисел. Для минимального и максимального параметра задать значения по умолчанию `[0,100)`
# (Использовать random_seed для возможности повторения результата)

# %% [markdown]
# ## 3] Написать декоратор, считающий время выполнения функции
# Составить декоратор, который выводит в консоль время выполнения декорируемой функции ( (*) выводить в консоль также название функции)

# %% [markdown]
# ## 4] Написать функцию записи в файл (*)
# Создать функцию декоратор, которая записывает сообщение в файл при вызове функции
#
# Записывается строка в формате:
#
#
#    **DD.MM.GGGG**|**HH:MM:SS**||**НАЗВАНИЕ ФУНКЦИИ**||**ВРЕМЯ ЕЕ ВЫПОЛНЕНИЯ**||**ПОЛЬЗОВАТЕЛЬ СИСТЕМЫ**

# %% [markdown]
# ## 5] Сравнить скорости map и list comprehension, filter и list comprehension
# ### map
# Из изначального массива сгенерировать новый по следующему правилу:
# "Каждое число является десятичным логарифмом исходного, округленное до целых".
#
# Сформировать данный массив спомощью map и list comprehension, сравнить скорости выполнения на разных длинах массива.
#
# Результат представить в виде короткого описания на markdown
#
# ### filter
# Из изначального массива сгенерировать новый по следующему правилу: "Оставить в нем только целые числа".
#
# Сформировать данный массив спомощью filter и list comprehension, сравнить скорости выполнения на разных длинах массива.
#
# Результат представить в виде короткого описания на markdown

# %%
n = 10 # Длина массива
source_n5_map = [i for i in range(1, n+1)] # Для map

source_n5_filter = [i/3 for i in range(1, n+1)] # Для filter
